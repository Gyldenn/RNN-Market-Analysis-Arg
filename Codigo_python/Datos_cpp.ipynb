# %% [markdown]
# En este archivo elijo segmentos del dataset para pasarle al main en c++

# %%
import pandas as pd
MEP = pd.read_csv('market_data_AL30/AL30_1205_CI_MEP.csv')

# %%
def seleccionar(inicio, final, activo):
    fragmento = activo.iloc[inicio:final]
    fragmento.to_csv("../Codigo_cpp/datos.csv", index = False)

# %%
seleccionar(300, 500, MEP)
